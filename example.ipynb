# %%
# to load dataset
from datasets import Datasets
from kd_triplet_datasets import KDTripletDataset

# for network and training
from network import Net_teacher, Net_student
from network_fit import NetworkFit

# to calculate the score
import savescore
from score import Score
from score_calc import ScoreCalc

# pytorch
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.optim as optim

# numpy and matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# initialize for  each parameters
DATASET = 'CIFAR10'
BATCH_SIZE = 100
NUM_WORKERS = 2

WEIGHT_DECAY = 0.007
LEARNING_RATE = 0.01
MOMENTUM = 0.9

SCHEDULER_STEPS = 100
SCHEDULER_GAMMA = 0.1

SEED = 1

EPOCH = 500

KD_LAMBDA = 2.0

TRIPLET_MARGINE = 5.0

# %%
# fixing the seed
torch.cuda.manual_seed_all(SEED)
torch.manual_seed(SEED)
np.random.seed(SEED)

# %%
# check if gpu is available
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("gpu mode")
else:
    device = torch.device("cpu")
    print("cpu mode")
# Out:
# gpu mode

# %%
# the name of results files
codename = 'kd_example'

fnnname = codename + "_fnn_model"

total_loss_name = codename + "_total_loss"
soft_loss_name = codename + "_soft_loss"
tri_loss_name = codename + "_tri_loss"
acc_name = codename + "_accuracy"

result_name = codename + "_result"

# %%
# load the data set
instance_datasets = Datasets(DATASET, BATCH_SIZE, NUM_WORKERS, shuffle = False)
data_sets = instance_datasets.create()

#trainloader = data_sets[0]
#testloader = data_sets[1]
classes = data_sets[2]
based_labels = data_sets[3]
trainset = data_sets[4]
testset = data_sets[5]
# Out:
# Dataset : CIFAR10
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# use the KD Triplet Dataset by using above dataset
tri_trainset = KDTripletDataset(trainset)
tri_testset = KDTripletDataset(testset)
tri_trainloader = torch.utils.data.DataLoader(tri_trainset, batch_size = BATCH_SIZE, shuffle = True, num_workers = NUM_WORKERS)
tri_testloader = torch.utils.data.DataLoader(tri_testset, batch_size = BATCH_SIZE, shuffle = False, num_workers = NUM_WORKERS)

# %%
# network and criterions
model_t = Net_teacher().to(device)
model_s = Net_student().to(device)

model_t.load_state_dict(torch.load("cnn_alex.pkl"))

optimizer = optim.SGD(model_s.parameters(), lr=LEARNING_RATE, momentum=MOMENTUM, weight_decay=WEIGHT_DECAY)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=SCHEDULER_STEPS, gamma=SCHEDULER_GAMMA)

soft_criterion = nn.CrossEntropyLoss()
triplet_loss = nn.TripletMarginLoss(margin=TRIPLET_MARGINE)

# %%
# fit for training and test
fit = NetworkFit(model_t, model_s, optimizer, soft_criterion, triplet_loss)

# %%
# to manage all scores
loss = Score()
loss_s = Score()
loss_t = Score()
correct = Score()
score_loss = [loss, loss_s, loss_t]
score_correct = [correct]
sc = ScoreCalc(score_loss, score_correct, BATCH_SIZE)

# %%
# training and test
for epoch in range(EPOCH):
    print('epoch', epoch+1)
    
    for (inputs, labels) in tri_trainloader:
        img1_t = inputs[0].to(device)
        img2_s = inputs[0].to(device)
        img3_s = inputs[1].to(device)
        
        images = (img1_t, img2_s, img3_s)
        
        label1_t = labels[0].to(device)
        label2_s = labels[0].to(device)
        label3_s = labels[1].to(device)
        
        label = (label1_t, label2_s, label3_s)
        
        fit.train(images, label, KD_LAMBDA)
        
    for (inputs, labels) in tri_trainloader:
        img1_t = inputs[0].to(device)
        img2_s = inputs[0].to(device)
        img3_s = inputs[1].to(device)
        
        images = (img1_t, img2_s, img3_s)
        
        label1_t = labels[0].to(device)
        label2_s = labels[0].to(device)
        label3_s = labels[1].to(device)
        
        label = (label1_t, label2_s, label3_s)
        
        losses, corrects = fit.test(images, label, KD_LAMBDA)
        
        sc.calc_sum(losses, corrects)
    
    sc.score_print(len(trainset))
    sc.score_append(len(trainset))
    sc.score_del()
    
    for (inputs, labels) in tri_testloader:
        img1_t = inputs[0].to(device)
        img2_s = inputs[0].to(device)
        img3_s = inputs[1].to(device)
        
        images = (img1_t, img2_s, img3_s)
        
        label1_t = labels[0].to(device)
        label2_s = labels[0].to(device)
        label3_s = labels[1].to(device)
        
        label = (label1_t, label2_s, label3_s)
        
        losses, corrects = fit.test(images, label, KD_LAMBDA)
        
        sc.calc_sum(losses, corrects)
    
    sc.score_print(len(testset), train = False)
    sc.score_append(len(testset), train = False)
    sc.score_del()
    
    scheduler.step()
# Out:
# epoch 1
# train mean loss=6.441203088760376, accuracy=0.4472
# test mean loss=6.384209885597229, accuracy=0.4507
# epoch 2
# train mean loss=5.3580407338142395, accuracy=0.55368
# test mean loss=5.481476616859436, accuracy=0.5407
# epoch 3
# train mean loss=4.517965421676636, accuracy=0.6212
# test mean loss=4.670205645561218, accuracy=0.6043
# epoch 4
# train mean loss=3.829943600177765, accuracy=0.6769
# test mean loss=4.098728365898133, accuracy=0.6516
# epoch 5
# train mean loss=3.7483384084701536, accuracy=0.68222
# test mean loss=4.095595626831055, accuracy=0.6521
# epoch 6
# train mean loss=3.4453044891357423, accuracy=0.70684
# test mean loss=3.805477108955383, accuracy=0.6792
# epoch 7
# train mean loss=3.609884603500366, accuracy=0.69638
# test mean loss=3.993795554637909, accuracy=0.667
# epoch 8
# train mean loss=3.747229362010956, accuracy=0.69416
# test mean loss=4.122958419322967, accuracy=0.6609
# epoch 9
# train mean loss=3.20278408908844, accuracy=0.73164
# test mean loss=3.6333179211616518, accuracy=0.7027
# epoch 10
# train mean loss=3.488153069972992, accuracy=0.70518
# test mean loss=3.903733022212982, accuracy=0.674
# epoch 11
# train mean loss=3.3514560880661013, accuracy=0.73042
# test mean loss=3.769123342037201, accuracy=0.6978
# epoch 12
# train mean loss=2.9259310193061827, accuracy=0.7528
# test mean loss=3.4394124126434327, accuracy=0.7173
# epoch 13
# train mean loss=3.1795585217475892, accuracy=0.73538
# test mean loss=3.6470056653022764, accuracy=0.7005
# epoch 14
# train mean loss=2.85161735367775, accuracy=0.75888
# test mean loss=3.323963289260864, accuracy=0.7253
# epoch 15
# train mean loss=3.036297287940979, accuracy=0.75722
# test mean loss=3.4884500432014467, accuracy=0.7197
# epoch 16
# train mean loss=2.9586877717971802, accuracy=0.757
# test mean loss=3.418719491958618, accuracy=0.7166
# epoch 17
# train mean loss=3.190121992111206, accuracy=0.73732
# test mean loss=3.6949509382247925, accuracy=0.7007
# epoch 18
# train mean loss=2.823544526576996, accuracy=0.7671
# test mean loss=3.3517950892448427, accuracy=0.7293
# epoch 19
# train mean loss=2.6657167088985445, accuracy=0.77292
# test mean loss=3.203035991191864, accuracy=0.73
# epoch 20
# train mean loss=2.8542718741893767, accuracy=0.77232
# test mean loss=3.319698712825775, accuracy=0.7329
# epoch 21
# train mean loss=2.6810082008838654, accuracy=0.77776
# test mean loss=3.2241318011283875, accuracy=0.7326
# epoch 22
# train mean loss=3.1087741088867187, accuracy=0.75006
# test mean loss=3.627599308490753, accuracy=0.7057
# epoch 23
# train mean loss=2.630037725687027, accuracy=0.78144
# test mean loss=3.1696903896331787, accuracy=0.7339
# epoch 24
# train mean loss=2.908583108663559, accuracy=0.75418
# test mean loss=3.443065650463104, accuracy=0.7153
# epoch 25
# train mean loss=2.9509066667556763, accuracy=0.7579
# test mean loss=3.5119520807266236, accuracy=0.7137
# epoch 26
# train mean loss=2.7363666439056398, accuracy=0.7856
# test mean loss=3.30382271528244, accuracy=0.7375
# epoch 27
# train mean loss=2.8422960159778596, accuracy=0.7651
# test mean loss=3.378953580856323, accuracy=0.7218
# epoch 28
# train mean loss=2.673719738483429, accuracy=0.78374
# test mean loss=3.2077272820472715, accuracy=0.738
# epoch 29
# train mean loss=2.668872362136841, accuracy=0.77984
# test mean loss=3.217556222677231, accuracy=0.7321
# epoch 30
# train mean loss=2.759473258972168, accuracy=0.77504
# test mean loss=3.344055700302124, accuracy=0.7317
# epoch 31
# train mean loss=2.701586744070053, accuracy=0.77476
# test mean loss=3.3020188283920286, accuracy=0.729
# epoch 32
# train mean loss=2.571674977302551, accuracy=0.78436
# test mean loss=3.146600103378296, accuracy=0.7374
# epoch 33
# train mean loss=2.714613695859909, accuracy=0.77526
# test mean loss=3.265102517604828, accuracy=0.7266
# epoch 34
# train mean loss=2.7257474222183227, accuracy=0.78292
# test mean loss=3.3007911682128905, accuracy=0.735
# epoch 35
# train mean loss=3.041478123664856, accuracy=0.73506
# test mean loss=3.5423902535438536, accuracy=0.6947
# epoch 36
# train mean loss=2.516895078420639, accuracy=0.79176
# test mean loss=3.0769056510925292, accuracy=0.7483
# epoch 37
# train mean loss=3.1956183936595917, accuracy=0.74998
# test mean loss=3.7369437074661254, accuracy=0.7048
# epoch 38
# train mean loss=2.689474715232849, accuracy=0.7817
# test mean loss=3.2265441322326662, accuracy=0.7407
# epoch 39
# train mean loss=2.5855633039474486, accuracy=0.78684
# test mean loss=3.1929456853866576, accuracy=0.7372
# epoch 40
# train mean loss=2.6270927107334137, accuracy=0.78072
# test mean loss=3.2061865019798277, accuracy=0.7327
# epoch 41
# train mean loss=2.552747984647751, accuracy=0.79408
# test mean loss=3.1787915062904357, accuracy=0.7429
# epoch 42
# train mean loss=2.8065462040901186, accuracy=0.7665
# test mean loss=3.3595693778991698, accuracy=0.7214
# epoch 43
# train mean loss=2.624297087430954, accuracy=0.78732
# test mean loss=3.222456157207489, accuracy=0.7391
# epoch 44
# train mean loss=2.863199372291565, accuracy=0.7698
# test mean loss=3.438993186950684, accuracy=0.7135
# epoch 45
# train mean loss=2.6544458174705508, accuracy=0.78274
# test mean loss=3.2477747416496277, accuracy=0.7357
# epoch 46
# train mean loss=2.660855313062668, accuracy=0.78192
# test mean loss=3.2560744857788086, accuracy=0.7336
# epoch 47
# train mean loss=2.752672805070877, accuracy=0.77748
# test mean loss=3.318643090724945, accuracy=0.7307
# epoch 48
# train mean loss=2.629742871046066, accuracy=0.78198
# test mean loss=3.1820908069610594, accuracy=0.7334
# epoch 49
# train mean loss=2.7743539242744446, accuracy=0.77566
# test mean loss=3.3727055907249452, accuracy=0.721
# epoch 50
# train mean loss=2.762824383020401, accuracy=0.77226
# test mean loss=3.3258021664619446, accuracy=0.7307
# epoch 51
# train mean loss=2.6832685577869415, accuracy=0.77016
# test mean loss=3.236787075996399, accuracy=0.728
# epoch 52
# train mean loss=2.5449846777915957, accuracy=0.78848
# test mean loss=3.108237066268921, accuracy=0.7408
# epoch 53
# train mean loss=2.622501426935196, accuracy=0.78618
# test mean loss=3.242715163230896, accuracy=0.7319
# epoch 54
# train mean loss=2.9544785866737366, accuracy=0.7643
# test mean loss=3.508810636997223, accuracy=0.7204
# epoch 55
# train mean loss=2.5202273399829864, accuracy=0.79358
# test mean loss=3.1634601068496706, accuracy=0.7425
# epoch 56
# train mean loss=3.2259319844245913, accuracy=0.73546
# test mean loss=3.8099011898040773, accuracy=0.6966
# epoch 57
# train mean loss=2.714968977689743, accuracy=0.77782
# test mean loss=3.2822322702407836, accuracy=0.725
# epoch 58
# train mean loss=2.549570096731186, accuracy=0.78796
# test mean loss=3.12205491065979, accuracy=0.7452
# epoch 59
# train mean loss=2.7334793603420255, accuracy=0.77232
# test mean loss=3.3293337488174437, accuracy=0.7207
# epoch 60
# train mean loss=3.187844876289368, accuracy=0.7447
# test mean loss=3.7410893654823303, accuracy=0.6997
# epoch 61
# train mean loss=2.719592367172241, accuracy=0.76818
# test mean loss=3.2900325298309325, accuracy=0.7268
# epoch 62
# train mean loss=2.4580164387226104, accuracy=0.7959
# test mean loss=3.0683811998367307, accuracy=0.7419
# epoch 63
# train mean loss=2.7810375394821167, accuracy=0.77638
# test mean loss=3.365528087615967, accuracy=0.7354
# epoch 64
# train mean loss=2.5179329183101653, accuracy=0.79404
# test mean loss=3.1273326897621154, accuracy=0.7446
# epoch 65
# train mean loss=2.5446738357543945, accuracy=0.7853
# test mean loss=3.1407645082473756, accuracy=0.7389
# epoch 66
# train mean loss=2.6222660167217255, accuracy=0.78526
# test mean loss=3.2532014417648316, accuracy=0.7326
# epoch 67
# train mean loss=2.6702762398719786, accuracy=0.78488
# test mean loss=3.2621777200698854, accuracy=0.7321
# epoch 68
# train mean loss=2.9414995241165163, accuracy=0.76006
# test mean loss=3.4953114557266236, accuracy=0.7186
# epoch 69
# train mean loss=2.4303952631950376, accuracy=0.80144
# test mean loss=3.0909176802635194, accuracy=0.7466
# epoch 70
# train mean loss=2.9182512273788452, accuracy=0.76018
# test mean loss=3.498276810646057, accuracy=0.7108
# epoch 71
# train mean loss=2.8562230310440064, accuracy=0.77008
# test mean loss=3.416011936664581, accuracy=0.7207
# epoch 72
# train mean loss=2.592862625837326, accuracy=0.78618
# test mean loss=3.1666372418403625, accuracy=0.7371
# epoch 73
# train mean loss=2.647416447877884, accuracy=0.78364
# test mean loss=3.2467708945274354, accuracy=0.7344
# epoch 74
# train mean loss=2.668660565853119, accuracy=0.7814
# test mean loss=3.2429051280021666, accuracy=0.7374
# epoch 75
# train mean loss=2.8822522864341735, accuracy=0.75604
# test mean loss=3.4597719168663024, accuracy=0.7069
# epoch 76
# train mean loss=2.367143252849579, accuracy=0.80108
# test mean loss=2.9759048628807068, accuracy=0.7519
# epoch 77
# train mean loss=2.676312999725342, accuracy=0.78272
# test mean loss=3.2687392449378967, accuracy=0.7363
# epoch 78
# train mean loss=2.622879806518555, accuracy=0.77856
# test mean loss=3.214217257499695, accuracy=0.7354
# epoch 79
# train mean loss=2.6559074964523317, accuracy=0.78558
# test mean loss=3.2754692220687867, accuracy=0.7311
# epoch 80
# train mean loss=2.5994314479827882, accuracy=0.78828
# test mean loss=3.2229650378227235, accuracy=0.7399
# epoch 81
# train mean loss=2.3851442594528196, accuracy=0.79824
# test mean loss=3.004010763168335, accuracy=0.7496
# epoch 82
# train mean loss=2.4285612342357634, accuracy=0.8001
# test mean loss=3.080884187221527, accuracy=0.7485
# epoch 83
# train mean loss=2.6633202724456786, accuracy=0.78388
# test mean loss=3.28539831161499, accuracy=0.7317
# epoch 84
# train mean loss=2.5560359115600586, accuracy=0.79034
# test mean loss=3.1589275097846983, accuracy=0.7404
# epoch 85
# train mean loss=2.615978943347931, accuracy=0.79072
# test mean loss=3.265114686489105, accuracy=0.7367
# epoch 86
# train mean loss=2.802832105636597, accuracy=0.77108
# test mean loss=3.420092842578888, accuracy=0.7182
# epoch 87
# train mean loss=2.6346389486789703, accuracy=0.78292
# test mean loss=3.2166613721847535, accuracy=0.7314
# epoch 88
# train mean loss=2.45076210975647, accuracy=0.80214
# test mean loss=3.079780840873718, accuracy=0.7499
# epoch 89
# train mean loss=2.398089333295822, accuracy=0.80752
# test mean loss=3.026019601821899, accuracy=0.756
# epoch 90
# train mean loss=2.798785839557648, accuracy=0.77936
# test mean loss=3.44845596075058, accuracy=0.7298
# epoch 91
# train mean loss=2.5612468602657317, accuracy=0.78692
# test mean loss=3.1479214596748353, accuracy=0.7342
# epoch 92
# train mean loss=2.424880926132202, accuracy=0.80548
# test mean loss=3.0522423148155213, accuracy=0.7563
# epoch 93
# train mean loss=2.6277164006233216, accuracy=0.78318
# test mean loss=3.230437159538269, accuracy=0.7354
# epoch 94
# train mean loss=2.681963655948639, accuracy=0.77768
# test mean loss=3.2863162660598757, accuracy=0.7286
# epoch 95
# train mean loss=2.836576506614685, accuracy=0.76244
# test mean loss=3.446219816207886, accuracy=0.7179
# epoch 96
# train mean loss=2.7058926866054533, accuracy=0.77796
# test mean loss=3.322278974056244, accuracy=0.7333
# epoch 97
# train mean loss=2.522596942663193, accuracy=0.7876
# test mean loss=3.1426640129089356, accuracy=0.7389
# epoch 98
# train mean loss=2.4939142928123474, accuracy=0.79252
# test mean loss=3.1396992063522338, accuracy=0.7479
# epoch 99
# train mean loss=3.1520460801124575, accuracy=0.76248
# test mean loss=3.7310835337638855, accuracy=0.7151
# epoch 100
# train mean loss=2.6303705468177796, accuracy=0.78706
# test mean loss=3.2544384360313416, accuracy=0.7425
# epoch 101
# train mean loss=1.7589136431217194, accuracy=0.8555
# test mean loss=2.447103120088577, accuracy=0.7964
# epoch 102
# train mean loss=1.6516956479549407, accuracy=0.86504
# test mean loss=2.389537296295166, accuracy=0.8008
# epoch 103
# train mean loss=1.598468239545822, accuracy=0.86892
# test mean loss=2.3816043293476103, accuracy=0.8059
# epoch 104
# train mean loss=1.5899808722734452, accuracy=0.87146
# test mean loss=2.3602353143692016, accuracy=0.8048
# epoch 105
# train mean loss=1.5551373306512832, accuracy=0.87488
# test mean loss=2.3718457007408142, accuracy=0.807
# epoch 106
# train mean loss=1.4939906494617463, accuracy=0.87958
# test mean loss=2.3152357721328736, accuracy=0.8061
# epoch 107
# train mean loss=1.507709421157837, accuracy=0.87862
# test mean loss=2.3435193145275117, accuracy=0.8032
# epoch 108
# train mean loss=1.4829017641544342, accuracy=0.8841
# test mean loss=2.3445707035064696, accuracy=0.8052
# epoch 109
# train mean loss=1.4736638613939286, accuracy=0.88314
# test mean loss=2.3365490078926086, accuracy=0.8059
# epoch 110
# train mean loss=1.5193496259450912, accuracy=0.88258
# test mean loss=2.388329472541809, accuracy=0.8028
# epoch 111
# train mean loss=1.4588684928417206, accuracy=0.88828
# test mean loss=2.3324504780769346, accuracy=0.8118
# epoch 112
# train mean loss=1.4309943294525147, accuracy=0.8883
# test mean loss=2.3304585349559783, accuracy=0.806
# epoch 113
# train mean loss=1.4110961533784867, accuracy=0.89082
# test mean loss=2.331855413913727, accuracy=0.8085
# epoch 114
# train mean loss=1.4077362864017486, accuracy=0.89144
# test mean loss=2.3232319855690005, accuracy=0.8118
# epoch 115
# train mean loss=1.3956015557050705, accuracy=0.8925
# test mean loss=2.3665005564689636, accuracy=0.8078
# epoch 116
# train mean loss=1.4102145669460298, accuracy=0.8904
# test mean loss=2.3649679338932037, accuracy=0.803
# epoch 117
# train mean loss=1.4250486466884613, accuracy=0.88918
# test mean loss=2.379513677358627, accuracy=0.8008
# epoch 118
# train mean loss=1.3825982085466384, accuracy=0.89528
# test mean loss=2.344762097597122, accuracy=0.8084
# epoch 119
# train mean loss=1.3470709953308106, accuracy=0.89616
# test mean loss=2.327747436761856, accuracy=0.8076
# epoch 120
# train mean loss=1.3395549187660216, accuracy=0.89962
# test mean loss=2.3251886105537416, accuracy=0.8085
# epoch 121
# train mean loss=1.3867452094554902, accuracy=0.89696
# test mean loss=2.354904826879501, accuracy=0.806
# epoch 122
# train mean loss=1.343445750951767, accuracy=0.8999
# test mean loss=2.3696787214279174, accuracy=0.8084
# epoch 123
# train mean loss=1.3442009624242783, accuracy=0.89948
# test mean loss=2.3714443743228912, accuracy=0.8052
# epoch 124
# train mean loss=1.3454011627435685, accuracy=0.9017
# test mean loss=2.3811872935295106, accuracy=0.8082
# epoch 125
# train mean loss=1.3872981181144715, accuracy=0.8963
# test mean loss=2.4210119330883026, accuracy=0.7983
# epoch 126
# train mean loss=1.313108074426651, accuracy=0.90304
# test mean loss=2.350963366031647, accuracy=0.8091
# epoch 127
# train mean loss=1.3737555564641952, accuracy=0.89964
# test mean loss=2.408325351476669, accuracy=0.8063
# epoch 128
# train mean loss=1.2796520174741746, accuracy=0.90702
# test mean loss=2.347932108640671, accuracy=0.8067
# epoch 129
# train mean loss=1.3154598956108092, accuracy=0.9059
# test mean loss=2.364776462316513, accuracy=0.8069
# epoch 130
# train mean loss=1.2800032283067704, accuracy=0.9067
# test mean loss=2.3574118638038635, accuracy=0.8102
# epoch 131
# train mean loss=1.3103752553462982, accuracy=0.90766
# test mean loss=2.3845298147201537, accuracy=0.8086
# epoch 132
# train mean loss=1.306756671667099, accuracy=0.90626
# test mean loss=2.413033341169357, accuracy=0.804
# epoch 133
# train mean loss=1.314368890285492, accuracy=0.9063
# test mean loss=2.418213254213333, accuracy=0.8036
# epoch 134
# train mean loss=1.324636266350746, accuracy=0.90482
# test mean loss=2.4457693123817443, accuracy=0.7999
# epoch 135
# train mean loss=1.3181489787101746, accuracy=0.90508
# test mean loss=2.414353107213974, accuracy=0.8029
# epoch 136
# train mean loss=1.2672148772478105, accuracy=0.91042
# test mean loss=2.366163041591644, accuracy=0.8052
# epoch 137
# train mean loss=1.2437660348415376, accuracy=0.9144
# test mean loss=2.390117048025131, accuracy=0.8096
# epoch 138
# train mean loss=1.3039599118232728, accuracy=0.9097
# test mean loss=2.442212932109833, accuracy=0.8012
# epoch 139
# train mean loss=1.2487694004774093, accuracy=0.91214
# test mean loss=2.375156581401825, accuracy=0.8056
# epoch 140
# train mean loss=1.2406096575260162, accuracy=0.91368
# test mean loss=2.4039489352703094, accuracy=0.8052
# epoch 141
# train mean loss=1.2929840630292893, accuracy=0.90952
# test mean loss=2.4668109226226806, accuracy=0.8019
# epoch 142
# train mean loss=1.2963598215579986, accuracy=0.91092
# test mean loss=2.425887061357498, accuracy=0.8044
# epoch 143
# train mean loss=1.222559718966484, accuracy=0.91298
# test mean loss=2.386951814889908, accuracy=0.8079
# epoch 144
# train mean loss=1.2746872539520264, accuracy=0.9085
# test mean loss=2.4350294601917266, accuracy=0.7962
# epoch 145
# train mean loss=1.2313389331102371, accuracy=0.91542
# test mean loss=2.393822680711746, accuracy=0.8067
# epoch 146
# train mean loss=1.2319736042022704, accuracy=0.91492
# test mean loss=2.4037616980075835, accuracy=0.8047
# epoch 147
# train mean loss=1.2352572666406632, accuracy=0.91736
# test mean loss=2.4482818949222565, accuracy=0.8048
# epoch 148
# train mean loss=1.2148641704320908, accuracy=0.91872
# test mean loss=2.3852949130535124, accuracy=0.81
# epoch 149
# train mean loss=1.192016839981079, accuracy=0.92016
# test mean loss=2.38336106300354, accuracy=0.8072
# epoch 150
# train mean loss=1.2148931748867036, accuracy=0.9145
# test mean loss=2.3967140233516693, accuracy=0.8032
# epoch 151
# train mean loss=1.2235144448280335, accuracy=0.9189
# test mean loss=2.3994442009925843, accuracy=0.8072
# epoch 152
# train mean loss=1.2770901582241059, accuracy=0.91226
# test mean loss=2.4602463912963866, accuracy=0.7984
# epoch 153
# train mean loss=1.2632408446073533, accuracy=0.91338
# test mean loss=2.4766527211666105, accuracy=0.8
# epoch 154
# train mean loss=1.2238754938840866, accuracy=0.91594
# test mean loss=2.412586989402771, accuracy=0.8035
# epoch 155
# train mean loss=1.1711466718912125, accuracy=0.92476
# test mean loss=2.3718540942668915, accuracy=0.81
# epoch 156
# train mean loss=1.2303022755384445, accuracy=0.91706
# test mean loss=2.4357896637916565, accuracy=0.8037
# epoch 157
# train mean loss=1.2230403629541398, accuracy=0.91632
# test mean loss=2.4334168076515197, accuracy=0.8006
# epoch 158
# train mean loss=1.1620753036737441, accuracy=0.92402
# test mean loss=2.3963042092323303, accuracy=0.8074
# epoch 159
# train mean loss=1.1960110092163085, accuracy=0.91754
# test mean loss=2.4046360802650453, accuracy=0.8048
# epoch 160
# train mean loss=1.167101610302925, accuracy=0.92272
# test mean loss=2.369661581516266, accuracy=0.8081
# epoch 161
# train mean loss=1.1781897007226945, accuracy=0.92354
# test mean loss=2.421496694087982, accuracy=0.8057
# epoch 162
# train mean loss=1.150979083418846, accuracy=0.9265
# test mean loss=2.391782326698303, accuracy=0.807
# epoch 163
# train mean loss=1.2081460931301118, accuracy=0.91888
# test mean loss=2.450140736103058, accuracy=0.8013
# epoch 164
# train mean loss=1.1937756459712983, accuracy=0.92282
# test mean loss=2.4231167709827424, accuracy=0.8077
# epoch 165
# train mean loss=1.174797149538994, accuracy=0.92174
# test mean loss=2.410270758867264, accuracy=0.8017
# epoch 166
# train mean loss=1.1852348777055741, accuracy=0.92148
# test mean loss=2.434585242271423, accuracy=0.8055
# epoch 167
# train mean loss=1.1740037289857865, accuracy=0.92364
# test mean loss=2.4226656877994537, accuracy=0.8085
# epoch 168
# train mean loss=1.1802971342802047, accuracy=0.92254
# test mean loss=2.4469062197208404, accuracy=0.8051
# epoch 169
# train mean loss=1.1974002075195314, accuracy=0.92224
# test mean loss=2.465272798538208, accuracy=0.805
# epoch 170
# train mean loss=1.132000120639801, accuracy=0.92572
# test mean loss=2.3857774209976195, accuracy=0.8047
# epoch 171
# train mean loss=1.2131148070096969, accuracy=0.92152
# test mean loss=2.463118591308594, accuracy=0.8027
# epoch 172
# train mean loss=1.1732570276260377, accuracy=0.92104
# test mean loss=2.443873394727707, accuracy=0.801
# epoch 173
# train mean loss=1.2224581394195557, accuracy=0.91358
# test mean loss=2.4872063636779784, accuracy=0.7987
# epoch 174
# train mean loss=1.1720843389034272, accuracy=0.925
# test mean loss=2.441296082735062, accuracy=0.8041
# epoch 175
# train mean loss=1.2108716768026353, accuracy=0.9202
# test mean loss=2.4622051763534545, accuracy=0.8015
# epoch 176
# train mean loss=1.2717750804424286, accuracy=0.91556
# test mean loss=2.5340744054317472, accuracy=0.7992
# epoch 177
# train mean loss=1.2019801969528199, accuracy=0.92148
# test mean loss=2.4844469940662384, accuracy=0.7996
# epoch 178
# train mean loss=1.127115593791008, accuracy=0.93136
# test mean loss=2.4358957946300506, accuracy=0.8068
# epoch 179
# train mean loss=1.1343941000699997, accuracy=0.92644
# test mean loss=2.4179879879951476, accuracy=0.8062
# epoch 180
# train mean loss=1.1786564406156539, accuracy=0.9272
# test mean loss=2.4789521431922914, accuracy=0.806
# epoch 181
# train mean loss=1.218157420039177, accuracy=0.92368
# test mean loss=2.4980997693538667, accuracy=0.8008
# epoch 182
# train mean loss=1.1516983872652053, accuracy=0.9288
# test mean loss=2.4356781482696532, accuracy=0.8102
# epoch 183
# train mean loss=1.2148868230581285, accuracy=0.92528
# test mean loss=2.4969836795330047, accuracy=0.8023
# epoch 184
# train mean loss=1.1734345965385438, accuracy=0.92424
# test mean loss=2.4453401589393615, accuracy=0.8024
# epoch 185
# train mean loss=1.1142648717164993, accuracy=0.9277
# test mean loss=2.3966718554496764, accuracy=0.8044
# epoch 186
# train mean loss=1.173439615726471, accuracy=0.92364
# test mean loss=2.4378012478351594, accuracy=0.8023
# epoch 187
# train mean loss=1.1941082210540772, accuracy=0.92182
# test mean loss=2.4902432310581206, accuracy=0.7963
# epoch 188
# train mean loss=1.1949496986865997, accuracy=0.91984
# test mean loss=2.5209625434875487, accuracy=0.7955
# epoch 189
# train mean loss=1.325914528608322, accuracy=0.91132
# test mean loss=2.6196507418155672, accuracy=0.7877
# epoch 190
# train mean loss=1.140899863243103, accuracy=0.92634
# test mean loss=2.4755821084976195, accuracy=0.8016
# epoch 191
# train mean loss=1.159881589770317, accuracy=0.92604
# test mean loss=2.4626594865322113, accuracy=0.8008
# epoch 192
# train mean loss=1.1037536458969117, accuracy=0.9304
# test mean loss=2.4270561373233797, accuracy=0.8035
# epoch 193
# train mean loss=1.116421859741211, accuracy=0.93088
# test mean loss=2.4530973196029664, accuracy=0.8053
# epoch 194
# train mean loss=1.177418965935707, accuracy=0.92782
# test mean loss=2.516321805715561, accuracy=0.8036
# epoch 195
# train mean loss=1.0937766015529633, accuracy=0.9331
# test mean loss=2.444528863430023, accuracy=0.8054
# epoch 196
# train mean loss=1.0967859208583832, accuracy=0.93092
# test mean loss=2.4180909037590026, accuracy=0.8028
# epoch 197
# train mean loss=1.0981275514364242, accuracy=0.93148
# test mean loss=2.42928165435791, accuracy=0.804
# epoch 198
# train mean loss=1.1127948517799378, accuracy=0.9308
# test mean loss=2.4340102291107177, accuracy=0.8092
# epoch 199
# train mean loss=1.1734370104074479, accuracy=0.92684
# test mean loss=2.4932364332675934, accuracy=0.7982
# epoch 200
# train mean loss=1.1889650673866272, accuracy=0.92516
# test mean loss=2.498293789625168, accuracy=0.8004
# epoch 201
# train mean loss=0.9709879547357559, accuracy=0.94316
# test mean loss=2.35585386633873, accuracy=0.8137
# epoch 202
# train mean loss=0.9569825296401977, accuracy=0.9437
# test mean loss=2.346665459871292, accuracy=0.8144
# epoch 203
# train mean loss=0.9549725731611252, accuracy=0.94486
# test mean loss=2.3487069725990297, accuracy=0.8147
# epoch 204
# train mean loss=0.9469801957011222, accuracy=0.94442
# test mean loss=2.3504233634471894, accuracy=0.8144
# epoch 205
# train mean loss=0.9410856913924217, accuracy=0.94436
# test mean loss=2.3407843327522277, accuracy=0.8141
# epoch 206
# train mean loss=0.9294077099561692, accuracy=0.94584
# test mean loss=2.355341933965683, accuracy=0.8125
# epoch 207
# train mean loss=0.9314538657665252, accuracy=0.9454
# test mean loss=2.3519985020160674, accuracy=0.8137
# epoch 208
# train mean loss=0.9341544646024704, accuracy=0.94642
# test mean loss=2.348214739561081, accuracy=0.8146
# epoch 209
# train mean loss=0.9481092542409897, accuracy=0.94548
# test mean loss=2.3597460448741914, accuracy=0.8143
# epoch 210
# train mean loss=0.927167910695076, accuracy=0.94662
# test mean loss=2.3581688845157625, accuracy=0.8146
# epoch 211
# train mean loss=0.9423399131298065, accuracy=0.94654
# test mean loss=2.366601287126541, accuracy=0.8124
# epoch 212
# train mean loss=0.9250896391868592, accuracy=0.94718
# test mean loss=2.362771443128586, accuracy=0.8138
# epoch 213
# train mean loss=0.9363033159971237, accuracy=0.9464
# test mean loss=2.3575011885166166, accuracy=0.8112
# epoch 214
# train mean loss=0.9338941134810448, accuracy=0.94646
# test mean loss=2.358901525735855, accuracy=0.8128
# epoch 215
# train mean loss=0.9402934857606888, accuracy=0.94676
# test mean loss=2.3671748638153076, accuracy=0.8126
# epoch 216
# train mean loss=0.9251458175182342, accuracy=0.9481
# test mean loss=2.363139854669571, accuracy=0.8145
# epoch 217
# train mean loss=0.9163458281755448, accuracy=0.9468
# test mean loss=2.3469742715358732, accuracy=0.8139
# epoch 218
# train mean loss=0.9153399496078491, accuracy=0.94786
# test mean loss=2.356445063352585, accuracy=0.814
# epoch 219
# train mean loss=0.9235716495513916, accuracy=0.94742
# test mean loss=2.3612838804721834, accuracy=0.8124
# epoch 220
# train mean loss=0.9183166548013687, accuracy=0.94822
# test mean loss=2.354693969488144, accuracy=0.8127
# epoch 221
# train mean loss=0.9139346301555633, accuracy=0.94802
# test mean loss=2.366282397508621, accuracy=0.8124
# epoch 222
# train mean loss=0.916473492026329, accuracy=0.94786
# test mean loss=2.35192307472229, accuracy=0.8119
# epoch 223
# train mean loss=0.9026237773895264, accuracy=0.94828
# test mean loss=2.35826492190361, accuracy=0.8102
# epoch 224
# train mean loss=0.9075576355457305, accuracy=0.94894
# test mean loss=2.3585541784763335, accuracy=0.8115
# epoch 225
# train mean loss=0.9198668431043625, accuracy=0.94738
# test mean loss=2.3711342036724092, accuracy=0.8109
# epoch 226
# train mean loss=0.9164418044090271, accuracy=0.94876
# test mean loss=2.362805713415146, accuracy=0.8102
# epoch 227
# train mean loss=0.9127076103687286, accuracy=0.94932
# test mean loss=2.371629728078842, accuracy=0.8122
# epoch 228
# train mean loss=0.9090430318713189, accuracy=0.94854
# test mean loss=2.3601742112636566, accuracy=0.8126
# epoch 229
# train mean loss=0.9018572731614113, accuracy=0.94882
# test mean loss=2.358076775074005, accuracy=0.8115
# epoch 230
# train mean loss=0.9074480072855949, accuracy=0.94846
# test mean loss=2.3679138624668123, accuracy=0.8119
# epoch 231
# train mean loss=0.9153440721035003, accuracy=0.94864
# test mean loss=2.367484511137009, accuracy=0.8105
# epoch 232
# train mean loss=0.902536607503891, accuracy=0.94878
# test mean loss=2.360841873884201, accuracy=0.812
# epoch 233
# train mean loss=0.9145239038467408, accuracy=0.94908
# test mean loss=2.3640314412117003, accuracy=0.8131
# epoch 234
# train mean loss=0.900444192647934, accuracy=0.94908
# test mean loss=2.369100304841995, accuracy=0.812
# epoch 235
# train mean loss=0.9014776850938797, accuracy=0.94938
# test mean loss=2.375517334938049, accuracy=0.8138
# epoch 236
# train mean loss=0.9097634961605072, accuracy=0.94872
# test mean loss=2.365200949907303, accuracy=0.8131
# epoch 237
# train mean loss=0.8911489953994751, accuracy=0.9489
# test mean loss=2.3619869208335875, accuracy=0.8111
# epoch 238
# train mean loss=0.9087886381149292, accuracy=0.94912
# test mean loss=2.3788191437721253, accuracy=0.8117
# epoch 239
# train mean loss=0.9016755270957947, accuracy=0.949
# test mean loss=2.374972016811371, accuracy=0.8119
# epoch 240
# train mean loss=0.8940144590735436, accuracy=0.94928
# test mean loss=2.3646747529506684, accuracy=0.81
# epoch 241
# train mean loss=0.9073387757539749, accuracy=0.95062
# test mean loss=2.3820318150520325, accuracy=0.8123
# epoch 242
# train mean loss=0.8998836012482643, accuracy=0.94966
# test mean loss=2.3755849969387053, accuracy=0.8101
# epoch 243
# train mean loss=0.8995652421712875, accuracy=0.9502
# test mean loss=2.380060086250305, accuracy=0.8104
# epoch 244
# train mean loss=0.9073961288332939, accuracy=0.95038
# test mean loss=2.376834055185318, accuracy=0.8087
# epoch 245
# train mean loss=0.9013514329195023, accuracy=0.94958
# test mean loss=2.373226135969162, accuracy=0.8115
# epoch 246
# train mean loss=0.9042701210975647, accuracy=0.9503
# test mean loss=2.3686290335655213, accuracy=0.81
# epoch 247
# train mean loss=0.895760795712471, accuracy=0.9506
# test mean loss=2.382105520963669, accuracy=0.8103
# epoch 248
# train mean loss=0.8992942993044853, accuracy=0.95048
# test mean loss=2.376645938158035, accuracy=0.8097
# epoch 249
# train mean loss=0.9059058759212494, accuracy=0.95046
# test mean loss=2.36423180103302, accuracy=0.81
# epoch 250
# train mean loss=0.8979957987070084, accuracy=0.94958
# test mean loss=2.3835857582092284, accuracy=0.8119
# epoch 251
# train mean loss=0.8952863682508468, accuracy=0.94994
# test mean loss=2.37057079911232, accuracy=0.8107
# epoch 252
# train mean loss=0.9032235861420631, accuracy=0.9495
# test mean loss=2.3818138098716735, accuracy=0.81
# epoch 253
# train mean loss=0.8804129430055618, accuracy=0.95126
# test mean loss=2.386317719221115, accuracy=0.8102
# epoch 254
# train mean loss=0.8963761684894562, accuracy=0.95108
# test mean loss=2.3803359413146974, accuracy=0.8131
# epoch 255
# train mean loss=0.9035131688714028, accuracy=0.9515
# test mean loss=2.3870459508895876, accuracy=0.8116
# epoch 256
# train mean loss=0.8919925668239593, accuracy=0.95088
# test mean loss=2.391669969558716, accuracy=0.8122
# epoch 257
# train mean loss=0.8980865902304649, accuracy=0.95174
# test mean loss=2.377169225215912, accuracy=0.8091
# epoch 258
# train mean loss=0.8792131150364876, accuracy=0.95136
# test mean loss=2.3751234459877013, accuracy=0.8106
# epoch 259
# train mean loss=0.8781829288005829, accuracy=0.9515
# test mean loss=2.3749612843990326, accuracy=0.8105
# epoch 260
# train mean loss=0.8905586820840835, accuracy=0.95076
# test mean loss=2.3860842001438143, accuracy=0.8117
# epoch 261
# train mean loss=0.8896604981422425, accuracy=0.95108
# test mean loss=2.37385164141655, accuracy=0.8128
# epoch 262
# train mean loss=0.8841638826727867, accuracy=0.95154
# test mean loss=2.3876566386222837, accuracy=0.8092
# epoch 263
# train mean loss=0.8791334400177002, accuracy=0.95176
# test mean loss=2.3874634671211243, accuracy=0.8129
# epoch 264
# train mean loss=0.8864135103225708, accuracy=0.95096
# test mean loss=2.3843702876567843, accuracy=0.8093
# epoch 265
# train mean loss=0.8870095580816268, accuracy=0.95138
# test mean loss=2.3826735734939577, accuracy=0.8109
# epoch 266
# train mean loss=0.899048653125763, accuracy=0.9514
# test mean loss=2.3889983093738554, accuracy=0.8098
# epoch 267
# train mean loss=0.8893813171982765, accuracy=0.95208
# test mean loss=2.400724477767944, accuracy=0.8092
# epoch 268
# train mean loss=0.8794549874067307, accuracy=0.95282
# test mean loss=2.3814010393619536, accuracy=0.8109
# epoch 269
# train mean loss=0.883754312813282, accuracy=0.9519
# test mean loss=2.3869540178775788, accuracy=0.8095
# epoch 270
# train mean loss=0.8818394901156426, accuracy=0.95224
# test mean loss=2.3881347250938414, accuracy=0.8117
# epoch 271
# train mean loss=0.8849350061416627, accuracy=0.95236
# test mean loss=2.382028068304062, accuracy=0.8102
# epoch 272
# train mean loss=0.8855044362545014, accuracy=0.95216
# test mean loss=2.3886453568935395, accuracy=0.81
# epoch 273
# train mean loss=0.884932538330555, accuracy=0.95208
# test mean loss=2.3943930435180665, accuracy=0.8093
# epoch 274
# train mean loss=0.8733926827311516, accuracy=0.9513
# test mean loss=2.3786696445941926, accuracy=0.8096
# epoch 275
# train mean loss=0.8715611904859543, accuracy=0.95222
# test mean loss=2.3801007473468783, accuracy=0.8113
# epoch 276
# train mean loss=0.8778477355241775, accuracy=0.9517
# test mean loss=2.3833995401859283, accuracy=0.8103
# epoch 277
# train mean loss=0.8813026889562606, accuracy=0.95244
# test mean loss=2.3833490550518035, accuracy=0.812
# epoch 278
# train mean loss=0.8779153703451157, accuracy=0.95356
# test mean loss=2.3954941391944886, accuracy=0.8102
# epoch 279
# train mean loss=0.8858797793388367, accuracy=0.9529
# test mean loss=2.3880321621894836, accuracy=0.8113
# epoch 280
# train mean loss=0.8738693215250969, accuracy=0.95268
# test mean loss=2.3809024143218993, accuracy=0.8108
# epoch 281
# train mean loss=0.8846546219587326, accuracy=0.95228
# test mean loss=2.4008580803871156, accuracy=0.8102
# epoch 282
# train mean loss=0.8839708943367004, accuracy=0.95306
# test mean loss=2.3823347270488737, accuracy=0.8118
# epoch 283
# train mean loss=0.8899077041149139, accuracy=0.95288
# test mean loss=2.3967730951309205, accuracy=0.8106
# epoch 284
# train mean loss=0.8795362138748168, accuracy=0.95344
# test mean loss=2.4008120489120484, accuracy=0.8101
# epoch 285
# train mean loss=0.8790100094079971, accuracy=0.95216
# test mean loss=2.3923529958724976, accuracy=0.8094
# epoch 286
# train mean loss=0.8850045790672302, accuracy=0.95272
# test mean loss=2.402219697237015, accuracy=0.8123
# epoch 287
# train mean loss=0.8723606761693955, accuracy=0.95452
# test mean loss=2.3863612723350527, accuracy=0.8098
# epoch 288
# train mean loss=0.8875194003582001, accuracy=0.95282
# test mean loss=2.395108355283737, accuracy=0.8114
# epoch 289
# train mean loss=0.8722024493217468, accuracy=0.95328
# test mean loss=2.39834889292717, accuracy=0.8089
# epoch 290
# train mean loss=0.8734110139012337, accuracy=0.95356
# test mean loss=2.392154105901718, accuracy=0.8093
# epoch 291
# train mean loss=0.8651697767972946, accuracy=0.95342
# test mean loss=2.3868080735206605, accuracy=0.8112
# epoch 292
# train mean loss=0.8690502110123635, accuracy=0.95296
# test mean loss=2.393232851028442, accuracy=0.8096
# epoch 293
# train mean loss=0.8664186003804207, accuracy=0.95518
# test mean loss=2.3996303141117097, accuracy=0.8094
# epoch 294
# train mean loss=0.8842465085983277, accuracy=0.95382
# test mean loss=2.4016574013233183, accuracy=0.8101
# epoch 295
# train mean loss=0.873078887104988, accuracy=0.95294
# test mean loss=2.4039265263080596, accuracy=0.8102
# epoch 296
# train mean loss=0.8717606759667397, accuracy=0.95108
# test mean loss=2.4033101594448087, accuracy=0.8096
# epoch 297
# train mean loss=0.8687297167778015, accuracy=0.95406
# test mean loss=2.395357871055603, accuracy=0.8115
# epoch 298
# train mean loss=0.8680898107886315, accuracy=0.95388
# test mean loss=2.4024309158325194, accuracy=0.8116
# epoch 299
# train mean loss=0.8745108369588852, accuracy=0.9537
# test mean loss=2.3957898628711702, accuracy=0.8111
# epoch 300
# train mean loss=0.873313663482666, accuracy=0.95406
# test mean loss=2.3992577397823336, accuracy=0.8094
# epoch 301
# train mean loss=0.8514592009186744, accuracy=0.9547
# test mean loss=2.385157641172409, accuracy=0.8097
# epoch 302
# train mean loss=0.844551488161087, accuracy=0.95494
# test mean loss=2.3886498832702636, accuracy=0.8099
# epoch 303
# train mean loss=0.8627092107534409, accuracy=0.9546
# test mean loss=2.387129465341568, accuracy=0.8084
# epoch 304
# train mean loss=0.8549540958404541, accuracy=0.95504
# test mean loss=2.3884728252887726, accuracy=0.809
# epoch 305
# train mean loss=0.8583752468824387, accuracy=0.95546
# test mean loss=2.387761381864548, accuracy=0.81
# epoch 306
# train mean loss=0.8550313649773598, accuracy=0.95486
# test mean loss=2.3869029307365417, accuracy=0.8093
# epoch 307
# train mean loss=0.8470615661740303, accuracy=0.95506
# test mean loss=2.387324070930481, accuracy=0.8108
# epoch 308
# train mean loss=0.8524852604866028, accuracy=0.95486
# test mean loss=2.3909119009971618, accuracy=0.8094
# epoch 309
# train mean loss=0.8434612883925438, accuracy=0.95498
# test mean loss=2.3881620931625367, accuracy=0.8104
# epoch 310
# train mean loss=0.8536420906782151, accuracy=0.9549
# test mean loss=2.385671614408493, accuracy=0.81
# epoch 311
# train mean loss=0.842775358915329, accuracy=0.95492
# test mean loss=2.3873685026168823, accuracy=0.8097
# epoch 312
# train mean loss=0.8465743532776833, accuracy=0.95484
# test mean loss=2.387740193605423, accuracy=0.8101
# epoch 313
# train mean loss=0.8497904051542282, accuracy=0.95528
# test mean loss=2.38714026927948, accuracy=0.8105
# epoch 314
# train mean loss=0.8561797581911087, accuracy=0.95482
# test mean loss=2.3901171255111695, accuracy=0.8099
# epoch 315
# train mean loss=0.8490369126796723, accuracy=0.95504
# test mean loss=2.3877462351322176, accuracy=0.8094
# epoch 316
# train mean loss=0.8462586247324944, accuracy=0.9552
# test mean loss=2.387938506603241, accuracy=0.8099
# epoch 317
# train mean loss=0.8514072750210762, accuracy=0.9552
# test mean loss=2.3872760581970214, accuracy=0.8101
# epoch 318
# train mean loss=0.8534862020611763, accuracy=0.95528
# test mean loss=2.3897748947143556, accuracy=0.8096
# epoch 319
# train mean loss=0.8521922403573989, accuracy=0.95552
# test mean loss=2.389921233654022, accuracy=0.8094
# epoch 320
# train mean loss=0.8533101885318756, accuracy=0.9554
# test mean loss=2.3885039389133453, accuracy=0.8087
# epoch 321
# train mean loss=0.8562783677577972, accuracy=0.95524
# test mean loss=2.388469299077988, accuracy=0.8086
# epoch 322
# train mean loss=0.8421894789338112, accuracy=0.95558
# test mean loss=2.3912073278427126, accuracy=0.8096
# epoch 323
# train mean loss=0.8492605873346328, accuracy=0.95566
# test mean loss=2.390563588142395, accuracy=0.809
# epoch 324
# train mean loss=0.8464012444019318, accuracy=0.9556
# test mean loss=2.3934170818328857, accuracy=0.8084
# epoch 325
# train mean loss=0.8492912285327912, accuracy=0.95498
# test mean loss=2.390176546573639, accuracy=0.8104
# epoch 326
# train mean loss=0.8479972400665283, accuracy=0.9548
# test mean loss=2.3897448205947875, accuracy=0.8099
# epoch 327
# train mean loss=0.8429712636470794, accuracy=0.95554
# test mean loss=2.3898016595840454, accuracy=0.8078
# epoch 328
# train mean loss=0.8543929244279862, accuracy=0.95554
# test mean loss=2.388778431415558, accuracy=0.8096
# epoch 329
# train mean loss=0.8432488310933113, accuracy=0.95524
# test mean loss=2.3894379806518553, accuracy=0.81
# epoch 330
# train mean loss=0.850208548784256, accuracy=0.9552
# test mean loss=2.389997099637985, accuracy=0.8094
# epoch 331
# train mean loss=0.8511778604388237, accuracy=0.9554
# test mean loss=2.387752788066864, accuracy=0.809
# epoch 332
# train mean loss=0.8520701060891152, accuracy=0.95522
# test mean loss=2.3877004301548004, accuracy=0.8091
# epoch 333
# train mean loss=0.8607721866369248, accuracy=0.95554
# test mean loss=2.388198823928833, accuracy=0.81
# epoch 334
# train mean loss=0.8455801961421967, accuracy=0.95522
# test mean loss=2.390074908733368, accuracy=0.8098
# epoch 335
# train mean loss=0.8610720065832138, accuracy=0.95514
# test mean loss=2.3913260447978972, accuracy=0.8107
# epoch 336
# train mean loss=0.8517715933918953, accuracy=0.95538
# test mean loss=2.3855094707012174, accuracy=0.8098
# epoch 337
# train mean loss=0.8446527389287949, accuracy=0.95574
# test mean loss=2.3901820576190946, accuracy=0.81
# epoch 338
# train mean loss=0.8484579868316651, accuracy=0.95534
# test mean loss=2.389311307668686, accuracy=0.8097
# epoch 339
# train mean loss=0.8477390468716621, accuracy=0.95564
# test mean loss=2.3867125844955446, accuracy=0.8093
# epoch 340
# train mean loss=0.8446502238512039, accuracy=0.95542
# test mean loss=2.3885198748111724, accuracy=0.8105
# epoch 341
# train mean loss=0.8483655594587326, accuracy=0.95516
# test mean loss=2.387470773458481, accuracy=0.8105
# epoch 342
# train mean loss=0.841130894780159, accuracy=0.95576
# test mean loss=2.388194235563278, accuracy=0.8088
# epoch 343
# train mean loss=0.8408964499235153, accuracy=0.95594
# test mean loss=2.387449017763138, accuracy=0.81
# epoch 344
# train mean loss=0.8441828840970993, accuracy=0.95544
# test mean loss=2.3872122025489806, accuracy=0.81
# epoch 345
# train mean loss=0.8533827755451202, accuracy=0.95506
# test mean loss=2.390488795042038, accuracy=0.8093
# epoch 346
# train mean loss=0.8462094439864158, accuracy=0.95514
# test mean loss=2.3906251549720765, accuracy=0.8107
# epoch 347
# train mean loss=0.8536077842712403, accuracy=0.95548
# test mean loss=2.392526032924652, accuracy=0.8097
# epoch 348
# train mean loss=0.8505872924923896, accuracy=0.95538
# test mean loss=2.39097323179245, accuracy=0.8088
# epoch 349
# train mean loss=0.8467211339473725, accuracy=0.95572
# test mean loss=2.39211777806282, accuracy=0.8098
# epoch 350
# train mean loss=0.8490669098496437, accuracy=0.95568
# test mean loss=2.3887640762329103, accuracy=0.8089
# epoch 351
# train mean loss=0.8556569210290909, accuracy=0.9551
# test mean loss=2.3884601080417633, accuracy=0.8098
# epoch 352
# train mean loss=0.8499510763287544, accuracy=0.95544
# test mean loss=2.3898822247982023, accuracy=0.8094
# epoch 353
# train mean loss=0.8485037455558777, accuracy=0.95568
# test mean loss=2.39284340262413, accuracy=0.8106
# epoch 354
# train mean loss=0.8504119009971619, accuracy=0.9556
# test mean loss=2.3913239002227784, accuracy=0.8096
# epoch 355
# train mean loss=0.8493180644512176, accuracy=0.95592
# test mean loss=2.392186914682388, accuracy=0.8095
# epoch 356
# train mean loss=0.8316846985816956, accuracy=0.95568
# test mean loss=2.3882565689086914, accuracy=0.8095
# epoch 357
# train mean loss=0.8525957992076874, accuracy=0.9557
# test mean loss=2.3908503007888795, accuracy=0.8089
# epoch 358
# train mean loss=0.8490514062047004, accuracy=0.95604
# test mean loss=2.38984370470047, accuracy=0.8096
# epoch 359
# train mean loss=0.8469185050725937, accuracy=0.95574
# test mean loss=2.38696883559227, accuracy=0.8084
# epoch 360
# train mean loss=0.8277946602106094, accuracy=0.95582
# test mean loss=2.389662448167801, accuracy=0.8093
# epoch 361
# train mean loss=0.8383101230859756, accuracy=0.95552
# test mean loss=2.3889357590675355, accuracy=0.8086
# epoch 362
# train mean loss=0.8505870631337166, accuracy=0.95564
# test mean loss=2.392036852836609, accuracy=0.8089
# epoch 363
# train mean loss=0.8392078856825829, accuracy=0.95568
# test mean loss=2.3914740324020385, accuracy=0.8099
# epoch 364
# train mean loss=0.8401444723010063, accuracy=0.95542
# test mean loss=2.388427698612213, accuracy=0.8099
# epoch 365
# train mean loss=0.8464899108409881, accuracy=0.9561
# test mean loss=2.3895107436180116, accuracy=0.809
# epoch 366
# train mean loss=0.8406668286919594, accuracy=0.95552
# test mean loss=2.3926939487457277, accuracy=0.8088
# epoch 367
# train mean loss=0.844823617875576, accuracy=0.9557
# test mean loss=2.3898860740661623, accuracy=0.8095
# epoch 368
# train mean loss=0.8371184019446373, accuracy=0.95526
# test mean loss=2.389406121969223, accuracy=0.8097
# epoch 369
# train mean loss=0.8433497914075851, accuracy=0.95602
# test mean loss=2.391659253835678, accuracy=0.8096
# epoch 370
# train mean loss=0.8448956950902938, accuracy=0.9557
# test mean loss=2.3917648708820343, accuracy=0.8091
# epoch 371
# train mean loss=0.8382661039829254, accuracy=0.95582
# test mean loss=2.389769413471222, accuracy=0.809
# epoch 372
# train mean loss=0.8318799242973328, accuracy=0.95608
# test mean loss=2.390009752511978, accuracy=0.8097
# epoch 373
# train mean loss=0.8439275025725365, accuracy=0.95518
# test mean loss=2.3917550230026245, accuracy=0.8099
# epoch 374
# train mean loss=0.8459786468744278, accuracy=0.95566
# test mean loss=2.3914295279979707, accuracy=0.8092
# epoch 375
# train mean loss=0.8482119757533073, accuracy=0.95572
# test mean loss=2.393460134267807, accuracy=0.81
# epoch 376
# train mean loss=0.8415436408519745, accuracy=0.95622
# test mean loss=2.3911046504974367, accuracy=0.8105
# epoch 377
# train mean loss=0.8475214888453484, accuracy=0.9559
# test mean loss=2.3929125595092775, accuracy=0.8095
# epoch 378
# train mean loss=0.8396615043282509, accuracy=0.95576
# test mean loss=2.3918482637405396, accuracy=0.8087
# epoch 379
# train mean loss=0.8498468511104583, accuracy=0.95562
# test mean loss=2.389490324258804, accuracy=0.8094
# epoch 380
# train mean loss=0.8464838927984237, accuracy=0.95574
# test mean loss=2.391494343280792, accuracy=0.8099
# epoch 381
# train mean loss=0.8388155950307846, accuracy=0.95502
# test mean loss=2.389901646375656, accuracy=0.8098
# epoch 382
# train mean loss=0.8383776055574417, accuracy=0.95572
# test mean loss=2.3899486696720125, accuracy=0.8093
# epoch 383
# train mean loss=0.8453338526487351, accuracy=0.95574
# test mean loss=2.393244416713715, accuracy=0.8099
# epoch 384
# train mean loss=0.8342869491577148, accuracy=0.95582
# test mean loss=2.3940733134746552, accuracy=0.8097
# epoch 385
# train mean loss=0.8477604020237922, accuracy=0.95598
# test mean loss=2.3915217828750612, accuracy=0.81
# epoch 386
# train mean loss=0.8414088660478591, accuracy=0.95566
# test mean loss=2.39220415353775, accuracy=0.8101
# epoch 387
# train mean loss=0.8449648851156235, accuracy=0.95566
# test mean loss=2.390940724611282, accuracy=0.8102
# epoch 388
# train mean loss=0.8469952523708344, accuracy=0.9557
# test mean loss=2.3930210733413695, accuracy=0.8099
# epoch 389
# train mean loss=0.8527794101834297, accuracy=0.95552
# test mean loss=2.389872758388519, accuracy=0.809
# epoch 390
# train mean loss=0.8368505159020424, accuracy=0.9562
# test mean loss=2.3936223793029785, accuracy=0.809
# epoch 391
# train mean loss=0.845788518667221, accuracy=0.95618
# test mean loss=2.394218512773514, accuracy=0.8095
# epoch 392
# train mean loss=0.8450848861932755, accuracy=0.95588
# test mean loss=2.391744269132614, accuracy=0.8092
# epoch 393
# train mean loss=0.8371615730524063, accuracy=0.9563
# test mean loss=2.3907294166088104, accuracy=0.8084
# epoch 394
# train mean loss=0.8452160559296608, accuracy=0.956
# test mean loss=2.394603452682495, accuracy=0.8102
# epoch 395
# train mean loss=0.8491338709592819, accuracy=0.95596
# test mean loss=2.393666979074478, accuracy=0.8092
# epoch 396
# train mean loss=0.8489345387220383, accuracy=0.95544
# test mean loss=2.394353942871094, accuracy=0.8089
# epoch 397
# train mean loss=0.8396117694973946, accuracy=0.95598
# test mean loss=2.390420775413513, accuracy=0.8101
# epoch 398
# train mean loss=0.8386496936678887, accuracy=0.9562
# test mean loss=2.3946257078647615, accuracy=0.8087
# epoch 399
# train mean loss=0.8494624977707863, accuracy=0.95596
# test mean loss=2.3926309549808504, accuracy=0.8096
# epoch 400
# train mean loss=0.8405433490872383, accuracy=0.95608
# test mean loss=2.3924157571792604, accuracy=0.8091
# epoch 401
# train mean loss=0.8411516627073288, accuracy=0.9562
# test mean loss=2.39143563747406, accuracy=0.8093
# epoch 402
# train mean loss=0.8452083282470703, accuracy=0.95622
# test mean loss=2.3916152918338778, accuracy=0.8094
# epoch 403
# train mean loss=0.8355627145171165, accuracy=0.95612
# test mean loss=2.3917471730709075, accuracy=0.8093
# epoch 404
# train mean loss=0.8366230334043503, accuracy=0.9561
# test mean loss=2.392004363536835, accuracy=0.8091
# epoch 405
# train mean loss=0.8499137997627259, accuracy=0.95622
# test mean loss=2.391802632808685, accuracy=0.8092
# epoch 406
# train mean loss=0.8388190704584122, accuracy=0.95626
# test mean loss=2.3917855644226074, accuracy=0.8092
# epoch 407
# train mean loss=0.8428823350071907, accuracy=0.95622
# test mean loss=2.3918236196041107, accuracy=0.8094
# epoch 408
# train mean loss=0.8343995255231857, accuracy=0.95618
# test mean loss=2.3915702044963836, accuracy=0.8087
# epoch 409
# train mean loss=0.8459552428722381, accuracy=0.95608
# test mean loss=2.391485823392868, accuracy=0.8089
# epoch 410
# train mean loss=0.8432373925447464, accuracy=0.95606
# test mean loss=2.391595731973648, accuracy=0.8089
# epoch 411
# train mean loss=0.847222227692604, accuracy=0.95594
# test mean loss=2.3912227606773375, accuracy=0.8088
# epoch 412
# train mean loss=0.8553287947177887, accuracy=0.95594
# test mean loss=2.391129651069641, accuracy=0.8093
# epoch 413
# train mean loss=0.8393514573574066, accuracy=0.95586
# test mean loss=2.3914716911315916, accuracy=0.8091
# epoch 414
# train mean loss=0.8424217979311943, accuracy=0.9559
# test mean loss=2.3911609172821047, accuracy=0.8091
# epoch 415
# train mean loss=0.837864118039608, accuracy=0.95594
# test mean loss=2.391562201976776, accuracy=0.8094
# epoch 416
# train mean loss=0.8430295791625977, accuracy=0.95616
# test mean loss=2.392201051712036, accuracy=0.8093
# epoch 417
# train mean loss=0.8412326079010963, accuracy=0.95608
# test mean loss=2.3914318668842314, accuracy=0.8093
# epoch 418
# train mean loss=0.8448847491145134, accuracy=0.95612
# test mean loss=2.3916472280025483, accuracy=0.809
# epoch 419
# train mean loss=0.8425996499657631, accuracy=0.95614
# test mean loss=2.391530590057373, accuracy=0.8091
# epoch 420
# train mean loss=0.8379995083808899, accuracy=0.95598
# test mean loss=2.391645475625992, accuracy=0.8086
# epoch 421
# train mean loss=0.8300702418088913, accuracy=0.95602
# test mean loss=2.3920974636077883, accuracy=0.8088
# epoch 422
# train mean loss=0.8438334993124008, accuracy=0.95614
# test mean loss=2.3928189516067504, accuracy=0.8095
# epoch 423
# train mean loss=0.8374291011095047, accuracy=0.95594
# test mean loss=2.3922447884082794, accuracy=0.809
# epoch 424
# train mean loss=0.8409445728063584, accuracy=0.95594
# test mean loss=2.391605442762375, accuracy=0.8096
# epoch 425
# train mean loss=0.8378641525506973, accuracy=0.95594
# test mean loss=2.391114740371704, accuracy=0.8095
# epoch 426
# train mean loss=0.8402301740050316, accuracy=0.95592
# test mean loss=2.3916467452049255, accuracy=0.8091
# epoch 427
# train mean loss=0.836567161142826, accuracy=0.95584
# test mean loss=2.391346765756607, accuracy=0.8094
# epoch 428
# train mean loss=0.8437556326985359, accuracy=0.95598
# test mean loss=2.3913791084289553, accuracy=0.8094
# epoch 429
# train mean loss=0.8457730389237403, accuracy=0.95598
# test mean loss=2.392192403078079, accuracy=0.809
# epoch 430
# train mean loss=0.8475425636172295, accuracy=0.95592
# test mean loss=2.391973991394043, accuracy=0.8092
# epoch 431
# train mean loss=0.8400891076922417, accuracy=0.9559
# test mean loss=2.391850417852402, accuracy=0.8096
# epoch 432
# train mean loss=0.8414155257940292, accuracy=0.95574
# test mean loss=2.392112662792206, accuracy=0.8094
# epoch 433
# train mean loss=0.8481139518022537, accuracy=0.9561
# test mean loss=2.392594392299652, accuracy=0.8085
# epoch 434
# train mean loss=0.8534032432436943, accuracy=0.95618
# test mean loss=2.3929556930065154, accuracy=0.809
# epoch 435
# train mean loss=0.8289709600806237, accuracy=0.95624
# test mean loss=2.392675198316574, accuracy=0.8092
# epoch 436
# train mean loss=0.8432171008586884, accuracy=0.95584
# test mean loss=2.3928577494621277, accuracy=0.8089
# epoch 437
# train mean loss=0.8394053547978401, accuracy=0.95588
# test mean loss=2.392518393993378, accuracy=0.8088
# epoch 438
# train mean loss=0.8328711771965027, accuracy=0.956
# test mean loss=2.3916684079170225, accuracy=0.8086
# epoch 439
# train mean loss=0.8375401728153229, accuracy=0.95598
# test mean loss=2.3918235325813293, accuracy=0.8091
# epoch 440
# train mean loss=0.8427963260412216, accuracy=0.95566
# test mean loss=2.3919351327419283, accuracy=0.8091
# epoch 441
# train mean loss=0.8421878404021264, accuracy=0.95598
# test mean loss=2.3924300241470338, accuracy=0.8089
# epoch 442
# train mean loss=0.8479605583548546, accuracy=0.956
# test mean loss=2.3928041815757752, accuracy=0.809
# epoch 443
# train mean loss=0.8507372176647187, accuracy=0.9559
# test mean loss=2.3923547863960266, accuracy=0.8085
# epoch 444
# train mean loss=0.8356859514713287, accuracy=0.9561
# test mean loss=2.392289241552353, accuracy=0.8094
# epoch 445
# train mean loss=0.8465608308315277, accuracy=0.95598
# test mean loss=2.3922763085365295, accuracy=0.8092
# epoch 446
# train mean loss=0.8358152835965157, accuracy=0.95588
# test mean loss=2.3922046852111816, accuracy=0.8093
# epoch 447
# train mean loss=0.8396282758116722, accuracy=0.95596
# test mean loss=2.392468822002411, accuracy=0.8088
# epoch 448
# train mean loss=0.8341814563274383, accuracy=0.95596
# test mean loss=2.3925222754478455, accuracy=0.8094
# epoch 449
# train mean loss=0.8515735998153686, accuracy=0.956
# test mean loss=2.392676807641983, accuracy=0.8093
# epoch 450
# train mean loss=0.8482005280256272, accuracy=0.956
# test mean loss=2.3927877879142763, accuracy=0.809
# epoch 451
# train mean loss=0.8484530359506607, accuracy=0.95606
# test mean loss=2.392839902639389, accuracy=0.8089
# epoch 452
# train mean loss=0.8444142541885375, accuracy=0.95608
# test mean loss=2.3923780059814455, accuracy=0.8092
# epoch 453
# train mean loss=0.8489576609134674, accuracy=0.95602
# test mean loss=2.3920046210289003, accuracy=0.8091
# epoch 454
# train mean loss=0.8389568318724632, accuracy=0.95594
# test mean loss=2.392206857204437, accuracy=0.8091
# epoch 455
# train mean loss=0.8439414393901825, accuracy=0.95604
# test mean loss=2.3927065253257753, accuracy=0.8095
# epoch 456
# train mean loss=0.8370146340727806, accuracy=0.95598
# test mean loss=2.3926025831699373, accuracy=0.8099
# epoch 457
# train mean loss=0.8488336578607559, accuracy=0.95596
# test mean loss=2.392262645959854, accuracy=0.8095
# epoch 458
# train mean loss=0.8304219697713852, accuracy=0.95602
# test mean loss=2.392255713939667, accuracy=0.8091
# epoch 459
# train mean loss=0.8424659115076065, accuracy=0.95588
# test mean loss=2.392330403327942, accuracy=0.8091
# epoch 460
# train mean loss=0.8381742549538612, accuracy=0.95588
# test mean loss=2.3920704066753387, accuracy=0.8091
# epoch 461
# train mean loss=0.8384991575479508, accuracy=0.95606
# test mean loss=2.392077521085739, accuracy=0.8087
# epoch 462
# train mean loss=0.8368043154478073, accuracy=0.9561
# test mean loss=2.3926812398433683, accuracy=0.8094
# epoch 463
# train mean loss=0.8445767505764962, accuracy=0.956
# test mean loss=2.3919466745853426, accuracy=0.8089
# epoch 464
# train mean loss=0.84623328602314, accuracy=0.95608
# test mean loss=2.3926720917224884, accuracy=0.8087
# epoch 465
# train mean loss=0.8401273683309555, accuracy=0.95604
# test mean loss=2.392357167005539, accuracy=0.8085
# epoch 466
# train mean loss=0.8450711269378662, accuracy=0.95608
# test mean loss=2.3922557055950167, accuracy=0.8086
# epoch 467
# train mean loss=0.8523621743917466, accuracy=0.95596
# test mean loss=2.3918067014217375, accuracy=0.8091
# epoch 468
# train mean loss=0.8455349695682526, accuracy=0.95606
# test mean loss=2.3923520815372465, accuracy=0.8085
# epoch 469
# train mean loss=0.837132796227932, accuracy=0.95582
# test mean loss=2.3920340764522554, accuracy=0.8086
# epoch 470
# train mean loss=0.8491266914010048, accuracy=0.95598
# test mean loss=2.3918258011341096, accuracy=0.8089
# epoch 471
# train mean loss=0.8478192913532258, accuracy=0.95578
# test mean loss=2.3914513099193573, accuracy=0.8089
# epoch 472
# train mean loss=0.83956874781847, accuracy=0.95578
# test mean loss=2.3917173731327055, accuracy=0.8094
# epoch 473
# train mean loss=0.8425423292517662, accuracy=0.95582
# test mean loss=2.391399230957031, accuracy=0.8091
# epoch 474
# train mean loss=0.8448304813504219, accuracy=0.9559
# test mean loss=2.391651071310043, accuracy=0.8094
# epoch 475
# train mean loss=0.8379226284027099, accuracy=0.956
# test mean loss=2.392246698141098, accuracy=0.8089
# epoch 476
# train mean loss=0.8424860116839409, accuracy=0.95578
# test mean loss=2.391779856681824, accuracy=0.8088
# epoch 477
# train mean loss=0.841255668580532, accuracy=0.9559
# test mean loss=2.3917478144168856, accuracy=0.8092
# epoch 478
# train mean loss=0.8469376478195191, accuracy=0.95602
# test mean loss=2.391723117828369, accuracy=0.8092
# epoch 479
# train mean loss=0.8427244243621826, accuracy=0.95606
# test mean loss=2.3918011105060577, accuracy=0.8087
# epoch 480
# train mean loss=0.837615021109581, accuracy=0.95604
# test mean loss=2.3920012056827544, accuracy=0.8088
# epoch 481
# train mean loss=0.8320076292157174, accuracy=0.95594
# test mean loss=2.3921434330940246, accuracy=0.809
# epoch 482
# train mean loss=0.8501288034915924, accuracy=0.95584
# test mean loss=2.392213867902756, accuracy=0.8088
# epoch 483
# train mean loss=0.8394626059532165, accuracy=0.95606
# test mean loss=2.3920185661315916, accuracy=0.8092
# epoch 484
# train mean loss=0.8462194671630859, accuracy=0.95586
# test mean loss=2.391943018436432, accuracy=0.809
# epoch 485
# train mean loss=0.836732121527195, accuracy=0.95588
# test mean loss=2.391660635471344, accuracy=0.8093
# epoch 486
# train mean loss=0.8367424409389496, accuracy=0.95592
# test mean loss=2.391793702840805, accuracy=0.8092
# epoch 487
# train mean loss=0.8386748284101486, accuracy=0.95584
# test mean loss=2.3919933557510378, accuracy=0.8086
# epoch 488
# train mean loss=0.8431817926168442, accuracy=0.95598
# test mean loss=2.3923942053318026, accuracy=0.8095
# epoch 489
# train mean loss=0.8457613319158555, accuracy=0.95584
# test mean loss=2.392999680042267, accuracy=0.809
# epoch 490
# train mean loss=0.8421931312084198, accuracy=0.95582
# test mean loss=2.393191398382187, accuracy=0.809
# epoch 491
# train mean loss=0.8399450409412385, accuracy=0.95616
# test mean loss=2.3928130972385406, accuracy=0.8093
# epoch 492
# train mean loss=0.8343150885105133, accuracy=0.95602
# test mean loss=2.392579746246338, accuracy=0.8092
# epoch 493
# train mean loss=0.845680839240551, accuracy=0.95594
# test mean loss=2.3923683083057403, accuracy=0.8089
# epoch 494
# train mean loss=0.8451983513832092, accuracy=0.95598
# test mean loss=2.3924307692050935, accuracy=0.8094
# epoch 495
# train mean loss=0.8371865702271462, accuracy=0.9558
# test mean loss=2.3926933431625366, accuracy=0.8087
# epoch 496
# train mean loss=0.8325594817996025, accuracy=0.956
# test mean loss=2.392936404943466, accuracy=0.8091
# epoch 497
# train mean loss=0.8426031863689423, accuracy=0.9561
# test mean loss=2.392618278264999, accuracy=0.8089
# epoch 498
# train mean loss=0.8444360103011131, accuracy=0.95596
# test mean loss=2.3918861997127534, accuracy=0.8092
# epoch 499
# train mean loss=0.8430315452218056, accuracy=0.95596
# test mean loss=2.3920996129512786, accuracy=0.809
# epoch 500
# train mean loss=0.8413595862388611, accuracy=0.95594
# test mean loss=2.391864928007126, accuracy=0.8091

# %%
# get the scores
train_losses, train_corrects = sc.get_value()
test_losses, test_corrects = sc.get_value(train = False)

# %%
# output the glaphs of the scores
torch.save(model_s.state_dict(), fnnname + '.pth')

savescore.plot_score(EPOCH, train_losses[0], test_losses[0], y_lim = 5.0, y_label = 'LOSS', legend = ['train loss', 'test loss'], title = 'total loss', filename = total_loss_name)

savescore.plot_score(EPOCH, train_losses[1], test_losses[1], y_lim = 5.0, y_label = 'LOSS', legend = ['train loss', 'test loss'], title = 'softmax loss', filename = soft_loss_name)

savescore.plot_score(EPOCH, train_losses[2], test_losses[2], y_lim = 5.0, y_label = 'LOSS', legend = ['train loss', 'test loss'], title = 'triplet loss', filename = tri_loss_name)

savescore.plot_score(EPOCH, train_corrects[0], test_corrects[0], y_lim = 1, y_label = 'ACCURACY', legend = ['train acc', 'test acc'], title = 'accuracy', filename = acc_name)

savescore.save_data(train_losses[0], test_losses[0], train_corrects[0], test_corrects[0], result_name)
